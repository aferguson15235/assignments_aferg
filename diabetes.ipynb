# %%
## import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

## logistic regression and data handling libraries
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics, svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics, svm
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

## neural network library
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout
from mlxtend.plotting import plot_confusion_matrix

# %%
# load the data set
data = pd.read_csv("diabetes.csv")
# check columns and see typical data set
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.info()
# see data types and find there's no null data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# overall histograms for dataset
data.hist(bins=20, figsize=(8,8))
plt.savefig("diabetes_plots/overall_hist.png")
# shows some weird spikes at zero for many features, suggests null data has been entered as 0

# %%
# correlation matrix for diabetes dataset
fig = plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),cmap="Blues",annot=True)
plt.savefig('diabetes_plots/corr_matrix.png', bbox_inches = 'tight')

# %%
# data cleaning
# setting all null values to the median rounded to nearest whole number to avoid data type errors
columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for j in columns:
    for i in range(data.shape[0]):
        if data.loc[i,j] == 0:
            data.loc[i,j] = round(data.median()[j])

data.hist(bins=20, figsize=(8,8))
plt.savefig("diabetes_plots/overall_hist_no_null.png")

# %%
# pie chart showing overall outcome

fig, ax = plt.subplots(figsize=(8,8))
data['Outcome'].sum()
plt.pie([data['Outcome'].sum(), data.shape[0] - data['Outcome'].sum()], labels=['Diabetic', 'Non-diabetic'], autopct='%1.1f%%')
ax.set_title("Overall diabetes statistics")
plt.savefig("diabetes_plots/outcome.png")

# %%
## Visualise the population age distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["Age"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["Age"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('Age Distribution for Diabetic Population')
plt.savefig("diabetes_plots/age_dist.png")

# %%
## Visualise the population BMI distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["BMI"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["BMI"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('BMI Distribution for Diabetic Population')
plt.savefig("diabetes_plots/BMI_dist.png")

# %%
## Visualise the population Diabetes pedigree function distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["DiabetesPedigreeFunction"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["DiabetesPedigreeFunction"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('Diabetes Pedigree Function Distribution for Diabetic Population')
plt.savefig("diabetes_plots/DPF_dist.png")

# %%
## Visualise the population Glucose distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["Glucose"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["Glucose"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('Glucose Distribution for Diabetic Population')
plt.savefig("diabetes_plots/glucose_dist.png")

# %%
# data standardisation and splitting
data_to_use = data.iloc[:,1:8]
data_to_target = data.iloc[:,8]

# split data 20% for testing 80% for training
x_train, x_test, y_train, y_test = train_test_split(data_to_use, data_to_target, test_size=0.2, random_state=6) 

# normalise data to fit mean 0 variance 1
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# create statistics dataframe to store accuracy and runtime etc.
acc_db = pd.DataFrame(columns=['Accuracy', 'Run Time (s)'])

# %%
# Logistic regression model
start = time.time()
log_reg = LogisticRegression()
# train the model
log_reg.fit(x_train, y_train)
# test model on test data
y_pred_log = log_reg.predict(x_test)
# measure runtime of model
run_time = time.time() - start

db = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_log})

acc_db.loc['Logistic regression'] = [metrics.accuracy_score(y_test,y_pred_log), run_time]

acc_db
# Out:
#                      Accuracy  Run Time (s)
# Logistic regression  0.785714      0.011904

# %%
# Gaussian naive bayes model

start = time.time()
gnb = GaussianNB()
# train the model
gnb.fit(x_train,y_train)
# test model on test data
y_pred_gnb = gnb.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction to dataframe
df_gnb = pd.DataFrame({"Actual": y_test, "Predicted": y_pred_gnb})

acc_db.loc['Gaussian naive Bayes'] = [metrics.accuracy_score(y_test, y_pred_gnb), run_time]

acc_db
# Out:
#                       Accuracy  Run Time (s)
# Logistic regression   0.785714      0.011904
# Gaussian naive Bayes  0.759740      0.002481

# %%
# find best k for knn model
bestacc = 0
for k in range(30):
    knn_model = KNeighborsClassifier(n_neighbors=k+1)
    knn_model.fit(x_train, y_train)
    y_pred_knn = knn_model.predict(x_test)
    if metrics.accuracy_score(y_test, y_pred_knn) > bestacc:
        bestk = k+1
        bestacc = metrics.accuracy_score(y_test, y_pred_knn)

# kNN model best number of neighbours

start = time.time()
knn_model = KNeighborsClassifier(n_neighbors=bestk)
# train the model
knn_model.fit(x_train, y_train)
# test model on test data
y_pred_knn = knn_model.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction to dataframe
df_knn = pd.DataFrame({"Actual": y_test, "Predicted": y_pred_knn})

acc_db.loc['k Neighbours k='+str(bestk)] = [metrics.accuracy_score(y_test, y_pred_knn), run_time]

acc_db
# Out:
#                       Accuracy  Run Time (s)
# Logistic regression   0.785714      0.011904
# Gaussian naive Bayes  0.759740      0.002481
# k Neighbours k=14     0.831169      0.009920

# %%
# support vector with variable kernel - options: {‘linear’, 'poly', ‘rbf’, ‘sigmoid’}
start = time.time()
kernel = 'linear'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

start = time.time()
kernel = 'poly'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

start = time.time()
kernel = 'rbf'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

start = time.time()
kernel = 'sigmoid'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

acc_db
# Out:
#                                Accuracy  Run Time (s)
# Logistic regression            0.785714      0.011904
# Gaussian naive Bayes           0.759740      0.002481
# k Neighbours k=14              0.831169      0.009920
# Support Vector kernel=linear   0.798701      0.017856
# Support Vector kernel=poly     0.714286      0.016367
# Support Vector kernel=rbf      0.792208      0.017366
# Support Vector kernel=sigmoid  0.733766      0.010416

# %%
# decision tree classifier models with variable depth and criterion
start = time.time()
decisionTree_model_gini = DecisionTreeClassifier(random_state=4000)
# train the model
decisionTree_model_gini.fit(x_train,y_train)
# test model on test data
y_pred_gini = decisionTree_model_gini.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Decision tree'] = [metrics.accuracy_score(y_test, y_pred_gini), run_time]

start = time.time()
decisionTree_model_entropy = DecisionTreeClassifier(criterion="entropy", random_state=4000)
# train the model
decisionTree_model_entropy.fit(x_train,y_train)
# test model on test data
y_pred_entropy = decisionTree_model_entropy.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Decision tree entropy'] = [metrics.accuracy_score(y_test, y_pred_entropy), run_time]

start = time.time()
decisionTree_model_depth3 = DecisionTreeClassifier(max_depth=3)
# train the model
decisionTree_model_depth3.fit(x_train,y_train)
# test model on test data
y_pred_depth3 = decisionTree_model_depth3.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Decision tree depth=3'] = [metrics.accuracy_score(y_test, y_pred_depth3), run_time]

acc_db
# Out:
#                                Accuracy  Run Time (s)
# Logistic regression            0.785714      0.011904
# Gaussian naive Bayes           0.759740      0.002481
# k Neighbours k=14              0.831169      0.009920
# Support Vector kernel=linear   0.798701      0.017856
# Support Vector kernel=poly     0.714286      0.016367
# Support Vector kernel=rbf      0.792208      0.017366
# Support Vector kernel=sigmoid  0.733766      0.010416
# Decision tree                  0.714286      0.010414
# Decision tree entropy          0.727273      0.004961
# Decision tree depth=3          0.746753      0.001983

# %%
# random forest classifier with variable n
start = time.time()
n = 1000
rfc = RandomForestClassifier(n_estimators=n)
# train the model
rfc.fit(x_train,y_train)
# test model on test data
y_pred_rfc = rfc.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Random Forest n='+str(n)] = [metrics.accuracy_score(y_test, y_pred_depth3), run_time]

acc_db
# Out:
#                                Accuracy  Run Time (s)
# Logistic regression            0.785714      0.011904
# Gaussian naive Bayes           0.759740      0.002481
# k Neighbours k=14              0.831169      0.009920
# Support Vector kernel=linear   0.798701      0.017856
# Support Vector kernel=poly     0.714286      0.016367
# Support Vector kernel=rbf      0.792208      0.017366
# Support Vector kernel=sigmoid  0.733766      0.010416
# Decision tree                  0.714286      0.010414
# Decision tree entropy          0.727273      0.004961
# Decision tree depth=3          0.746753      0.001983
# Random Forest n=1000           0.746753      1.704256

# %%
# confusion matrix for best logistic regression model
conf_mat_knn = confusion_matrix(y_test, y_pred_knn)
fig, ax = plt.subplots(figsize=(6,4))
sns.heatmap(conf_mat_knn/np.sum(conf_mat_knn), annot=True, fmt='.2f', annot_kws = {'size':25})
ax.set_ylabel("Actual outcome")
ax.set_xlabel("Predicted outcome")
plt.savefig("diabetes_plots/confusion_matrix_knn.png")

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88       103
#            1       0.82      0.63      0.71        51
#
#     accuracy                           0.83       154
#    macro avg       0.83      0.78      0.80       154
# weighted avg       0.83      0.83      0.82       154

# %%
fpr, tpr = roc_curve(y_test, y_pred_knn)[0:2]
auc = roc_auc_score(y_test, y_pred_knn)

plt.plot(fpr, tpr, color='orange', label=f'ROC, AUC = {auc}')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.savefig("diabetes_plots/roc_knn.png")

# %%
## neural network
start = time.time()
model = Sequential()

##set up the layers
## input layer
model.add(Dense(units= 100, kernel_initializer= 'uniform', activation = 'leaky_relu', input_dim = 7)) 
## hidden layer 1 
model.add(Dense(units= 30, kernel_initializer= 'uniform', activation = 'leaky_relu')) 
##regularization 1
#model.add(Dropout(0.4)) # setting 40% of the data to zero to avoid overfitting
## hidden layer 2
#model.add(Dense(units= 20, kernel_initializer= 'uniform', activation = 'leaky_relu')) 
## regularization 2
model.add(Dropout(0.2)) # another regularisation to avoid overfitting
## output layer
model.add(Dense(units= 1, kernel_initializer= 'uniform', activation = 'sigmoid')) 

## compiling the ANN
model.compile(optimizer = 'adam', loss ='binary_crossentropy', metrics = ['accuracy'])

## train the model with early stopping after enough consecutive epochs without improvement in loss
callback = EarlyStopping(monitor='loss', patience=8)
history = model.fit(x_train, y_train, batch_size = 25, epochs = 100, validation_split=0.25, callbacks=[callback])

## test the model
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
run_time = time.time() - start

print(f"Total run time is: {run_time}")
history_df = pd.DataFrame(history.history)
# Out:
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6378 - loss: 0.6906 - val_accuracy: 0.7143 - val_loss: 0.6776
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7411 - loss: 0.6668 - val_accuracy: 0.7208 - val_loss: 0.6221
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7582 - loss: 0.5873 - val_accuracy: 0.7273 - val_loss: 0.5420
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7526 - loss: 0.5192 - val_accuracy: 0.7532 - val_loss: 0.5261
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7728 - loss: 0.4517 - val_accuracy: 0.7727 - val_loss: 0.5129
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7632 - loss: 0.4859 - val_accuracy: 0.7792 - val_loss: 0.4995
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.4778 - val_accuracy: 0.7792 - val_loss: 0.4975
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7624 - loss: 0.4609 - val_accuracy: 0.7792 - val_loss: 0.4945
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7431 - loss: 0.4895 - val_accuracy: 0.7792 - val_loss: 0.4865
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7652 - loss: 0.4805 - val_accuracy: 0.7922 - val_loss: 0.4807
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7586 - loss: 0.4912 - val_accuracy: 0.7857 - val_loss: 0.4831
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7672 - loss: 0.4633 - val_accuracy: 0.7792 - val_loss: 0.4825
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7798 - loss: 0.4615 - val_accuracy: 0.7727 - val_loss: 0.4797
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7898 - loss: 0.4461 - val_accuracy: 0.7792 - val_loss: 0.4801
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8038 - loss: 0.4404 - val_accuracy: 0.7727 - val_loss: 0.4850
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7804 - loss: 0.4494 - val_accuracy: 0.7792 - val_loss: 0.4809
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7817 - loss: 0.4545 - val_accuracy: 0.7792 - val_loss: 0.4824
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7862 - loss: 0.4593 - val_accuracy: 0.7792 - val_loss: 0.4828
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7888 - loss: 0.4332 - val_accuracy: 0.7792 - val_loss: 0.4839
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7800 - loss: 0.4418 - val_accuracy: 0.7792 - val_loss: 0.4834
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7885 - loss: 0.4259 - val_accuracy: 0.7792 - val_loss: 0.4856
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7582 - loss: 0.4675 - val_accuracy: 0.7727 - val_loss: 0.4831
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7757 - loss: 0.4374 - val_accuracy: 0.7792 - val_loss: 0.4831
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7402 - loss: 0.4627 - val_accuracy: 0.7792 - val_loss: 0.4813
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7775 - loss: 0.4428 - val_accuracy: 0.7792 - val_loss: 0.4848
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7527 - loss: 0.4747 - val_accuracy: 0.7792 - val_loss: 0.4836
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7805 - loss: 0.4433 - val_accuracy: 0.7792 - val_loss: 0.4866
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7736 - loss: 0.4349 - val_accuracy: 0.7857 - val_loss: 0.4849
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - loss: 0.4341 - val_accuracy: 0.7857 - val_loss: 0.4847
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7752 - loss: 0.4241 - val_accuracy: 0.7857 - val_loss: 0.4859
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7822 - loss: 0.4255 - val_accuracy: 0.7857 - val_loss: 0.4877
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7607 - loss: 0.4181 - val_accuracy: 0.7792 - val_loss: 0.4819
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - loss: 0.4310 - val_accuracy: 0.7857 - val_loss: 0.4850
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7783 - loss: 0.4115 - val_accuracy: 0.7857 - val_loss: 0.4855
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7638 - loss: 0.4427 - val_accuracy: 0.7857 - val_loss: 0.4884
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7699 - loss: 0.4365 - val_accuracy: 0.7857 - val_loss: 0.4886
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7723 - loss: 0.4409 - val_accuracy: 0.7857 - val_loss: 0.4879
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7910 - loss: 0.4184 - val_accuracy: 0.7792 - val_loss: 0.4913
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7867 - loss: 0.4098 - val_accuracy: 0.7857 - val_loss: 0.4863
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7769 - loss: 0.4268 - val_accuracy: 0.7792 - val_loss: 0.4898
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7735 - loss: 0.4246 - val_accuracy: 0.7857 - val_loss: 0.4892
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7840 - loss: 0.4320 - val_accuracy: 0.7857 - val_loss: 0.4943
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7921 - loss: 0.4334 - val_accuracy: 0.7857 - val_loss: 0.4873
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8143 - loss: 0.4107 - val_accuracy: 0.7857 - val_loss: 0.4894
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8018 - loss: 0.4116 - val_accuracy: 0.7857 - val_loss: 0.4896
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7967 - loss: 0.4032 - val_accuracy: 0.7857 - val_loss: 0.4932
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7807 - loss: 0.4259 - val_accuracy: 0.7792 - val_loss: 0.4893
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7975 - loss: 0.4094 - val_accuracy: 0.7792 - val_loss: 0.4920
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8097 - loss: 0.4259 - val_accuracy: 0.7857 - val_loss: 0.4924
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8035 - loss: 0.4272 - val_accuracy: 0.7857 - val_loss: 0.4872
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7976 - loss: 0.3984 - val_accuracy: 0.7792 - val_loss: 0.4962
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8050 - loss: 0.4167 - val_accuracy: 0.7792 - val_loss: 0.4969
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8044 - loss: 0.4134 - val_accuracy: 0.7857 - val_loss: 0.4923
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7839 - loss: 0.4193 - val_accuracy: 0.7857 - val_loss: 0.4966
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8166 - loss: 0.3945 - val_accuracy: 0.7792 - val_loss: 0.4920
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7942 - loss: 0.4216 - val_accuracy: 0.7857 - val_loss: 0.4969
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7869 - loss: 0.4262 - val_accuracy: 0.7727 - val_loss: 0.4961
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8048 - loss: 0.4059 - val_accuracy: 0.7792 - val_loss: 0.4938
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7944 - loss: 0.3986 - val_accuracy: 0.7857 - val_loss: 0.4952
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7928 - loss: 0.4278 - val_accuracy: 0.7792 - val_loss: 0.5000
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7999 - loss: 0.4011 - val_accuracy: 0.7857 - val_loss: 0.4977
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8061 - loss: 0.4079 - val_accuracy: 0.7792 - val_loss: 0.4970
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8290 - loss: 0.3747 - val_accuracy: 0.7857 - val_loss: 0.4993
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8181 - loss: 0.3903 - val_accuracy: 0.7792 - val_loss: 0.5002
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7944 - loss: 0.4247 - val_accuracy: 0.7857 - val_loss: 0.4987
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8136 - loss: 0.3775 - val_accuracy: 0.7792 - val_loss: 0.4997
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8050 - loss: 0.3863 - val_accuracy: 0.7792 - val_loss: 0.4999
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8054 - loss: 0.4114 - val_accuracy: 0.7727 - val_loss: 0.4930
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7887 - loss: 0.4410 - val_accuracy: 0.7792 - val_loss: 0.5025
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8158 - loss: 0.3839 - val_accuracy: 0.7792 - val_loss: 0.4982
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7902 - loss: 0.4301 - val_accuracy: 0.7792 - val_loss: 0.5064
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8094 - loss: 0.3916 - val_accuracy: 0.7792 - val_loss: 0.5056
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8066 - loss: 0.3928 - val_accuracy: 0.7792 - val_loss: 0.5066
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7909 - loss: 0.4241 - val_accuracy: 0.7792 - val_loss: 0.5023
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8032 - loss: 0.4183 - val_accuracy: 0.7857 - val_loss: 0.4989
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8490 - loss: 0.3375 - val_accuracy: 0.7857 - val_loss: 0.5077
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8162 - loss: 0.3904 - val_accuracy: 0.7857 - val_loss: 0.5023
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8007 - loss: 0.4150 - val_accuracy: 0.7792 - val_loss: 0.5078
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7950 - loss: 0.3927 - val_accuracy: 0.7922 - val_loss: 0.5062
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7945 - loss: 0.4141 - val_accuracy: 0.7792 - val_loss: 0.5116
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8232 - loss: 0.3775 - val_accuracy: 0.7857 - val_loss: 0.5126
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8056 - loss: 0.3653 - val_accuracy: 0.7857 - val_loss: 0.5074
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8055 - loss: 0.3834 - val_accuracy: 0.7857 - val_loss: 0.5117
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7973 - loss: 0.3850 - val_accuracy: 0.7857 - val_loss: 0.5072
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8228 - loss: 0.3977 - val_accuracy: 0.7857 - val_loss: 0.5096
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7981 - loss: 0.3911 - val_accuracy: 0.7857 - val_loss: 0.5166
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7905 - loss: 0.3820 - val_accuracy: 0.7857 - val_loss: 0.5152
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7868 - loss: 0.3970 - val_accuracy: 0.7792 - val_loss: 0.5126
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8068 - loss: 0.3493 - val_accuracy: 0.7727 - val_loss: 0.5222
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8109 - loss: 0.3715 - val_accuracy: 0.7792 - val_loss: 0.5135
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8167 - loss: 0.3766 - val_accuracy: 0.7792 - val_loss: 0.5201
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8103 - loss: 0.3647 - val_accuracy: 0.7792 - val_loss: 0.5059
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8186 - loss: 0.3673 - val_accuracy: 0.7792 - val_loss: 0.5173
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8129 - loss: 0.3706 - val_accuracy: 0.7727 - val_loss: 0.5119
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8271 - loss: 0.3620 - val_accuracy: 0.7727 - val_loss: 0.5195
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8143 - loss: 0.3529 - val_accuracy: 0.7857 - val_loss: 0.5231
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7865 - loss: 0.3739 - val_accuracy: 0.7727 - val_loss: 0.5208
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8182 - loss: 0.3822 - val_accuracy: 0.7792 - val_loss: 0.5238
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8002 - loss: 0.3880 - val_accuracy: 0.7727 - val_loss: 0.5304
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8058 - loss: 0.3613 - val_accuracy: 0.7792 - val_loss: 0.5318
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Total run time is: 9.60778522491455

# %%
# plot of training and validation loss
plt.plot(history_df.loc[:, ['loss']], "#CD5C5C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")
plt.savefig("diabetes_plots/loss_chart.png")

# %%
# Training and validation accuracy plot
plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("diabetes_plots/accuracy_chart.png")

# %%
# confusion matrix for neural network
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot = True, annot_kws = {'size':25})
plt.ylabel("Actual outcome")
plt.xlabel("Predicted outcome")
plt.savefig("diabetes_plots/confusion_matrix_ann.png")

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88       103
#            1       0.78      0.69      0.73        51
#
#     accuracy                           0.83       154
#    macro avg       0.82      0.79      0.80       154
# weighted avg       0.83      0.83      0.83       154

# %%
fpr, tpr = roc_curve(y_test, y_pred)[0:2]
auc = roc_auc_score(y_test, y_pred)

plt.plot(fpr, tpr, color='orange', label=f'ROC, AUC = {auc}')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.savefig("diabetes_plots/roc_ann.png")

# %%
# accuracy for final neural network
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.8311688311688312
