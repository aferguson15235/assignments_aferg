# %%
## import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

## logistic regression and data handling libraries
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics, svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics, svm
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

## neural network library
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout
from mlxtend.plotting import plot_confusion_matrix

# %%
# load the data set
data = pd.read_csv("diabetes.csv")
# check columns and see typical data set
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.info()
# see data types and find there's no null data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# overall histograms for dataset
data.hist(bins=20, figsize=(8,8))
plt.savefig("diabetes_plots/overall_hist.png")
# shows some weird spikes at zero for many features, suggests null data has been entered as 0

# %%
# correlation matrix for diabetes dataset
fig = plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),cmap="Blues",annot=True)
plt.savefig('diabetes_plots/corr_matrix.png', bbox_inches = 'tight')

# %%
# data cleaning
# setting all null values to the median rounded to nearest whole number to avoid data type errors
columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for j in columns:
    for i in range(data.shape[0]):
        if data.loc[i,j] == 0:
            data.loc[i,j] = round(data.median()[j])

data.hist(bins=20, figsize=(8,8))
plt.savefig("diabetes_plots/overall_hist_no_null.png")

# %%
# pie chart showing overall outcome

fig, ax = plt.subplots(figsize=(8,8))
data['Outcome'].sum()
plt.pie([data['Outcome'].sum(), data.shape[0] - data['Outcome'].sum()], labels=['Diabetic', 'Non-diabetic'], autopct='%1.1f%%')
ax.set_title("Overall diabetes statistics")
plt.savefig("diabetes_plots/outcome.png")

# %%
## Visualise the population age distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["Age"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["Age"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('Age Distribution for Diabetic Population')
plt.savefig("diabetes_plots/age_dist.png")

# %%
## Visualise the population BMI distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["BMI"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["BMI"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('BMI Distribution for Diabetic Population')
plt.savefig("diabetes_plots/BMI_dist.png")

# %%
## Visualise the population Diabetes pedigree function distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["DiabetesPedigreeFunction"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["DiabetesPedigreeFunction"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('Diabetes Pedigree Function Distribution for Diabetic Population')
plt.savefig("diabetes_plots/DPF_dist.png")

# %%
## Visualise the population Glucose distribution between the diabetic and non-diabetic
plt.figure(figsize=(16,8))
ax = sns.histplot(data["Glucose"][data.Outcome == 0], color="blue", kde=True), sns.histplot(data["Glucose"][data.Outcome == 1], color="red", kde=True)
plt.legend(['Non-diabetic', 'Diabetic'])
plt.title('Glucose Distribution for Diabetic Population')
plt.savefig("diabetes_plots/glucose_dist.png")

# %%
# data standardisation and splitting
data_to_use = data.iloc[:,1:8]
data_to_target = data.iloc[:,8]

# split data 20% for testing 80% for training
x_train, x_test, y_train, y_test = train_test_split(data_to_use, data_to_target, test_size=0.2, random_state=6) 

# normalise data to fit mean 0 variance 1
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# create statistics dataframe to store accuracy and runtime etc.
acc_db = pd.DataFrame(columns=['Accuracy', 'Run Time (s)'])

# %%
# Logistic regression model
start = time.time()
log_reg = LogisticRegression()
# train the model
log_reg.fit(x_train, y_train)
# test model on test data
y_pred_log = log_reg.predict(x_test)
# measure runtime of model
run_time = time.time() - start

db = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_log})

acc_db.loc['Logistic regression'] = [metrics.accuracy_score(y_test,y_pred_log), run_time]

acc_db
# Out:
#                      Accuracy  Run Time (s)
# Logistic regression  0.785714      0.003473

# %%
# Gaussian naive bayes model

start = time.time()
gnb = GaussianNB()
# train the model
gnb.fit(x_train,y_train)
# test model on test data
y_pred_gnb = gnb.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction to dataframe
df_gnb = pd.DataFrame({"Actual": y_test, "Predicted": y_pred_gnb})

acc_db.loc['Gaussian naive Bayes'] = [metrics.accuracy_score(y_test, y_pred_gnb), run_time]

acc_db
# Out:
#                       Accuracy  Run Time (s)
# Logistic regression   0.785714      0.003473
# Gaussian naive Bayes  0.759740      0.001984

# %%
# find best k for knn model
bestacc = 0
for k in range(30):
    knn_model = KNeighborsClassifier(n_neighbors=k+1)
    knn_model.fit(x_train, y_train)
    y_pred_knn = knn_model.predict(x_test)
    if metrics.accuracy_score(y_test, y_pred_knn) > bestacc:
        bestk = k+1
        bestacc = metrics.accuracy_score(y_test, y_pred_knn)

# kNN model best number of neighbours

start = time.time()
knn_model = KNeighborsClassifier(n_neighbors=bestk)
# train the model
knn_model.fit(x_train, y_train)
# test model on test data
y_pred_knn = knn_model.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction to dataframe
df_knn = pd.DataFrame({"Actual": y_test, "Predicted": y_pred_knn})

acc_db.loc['k Neighbours k='+str(bestk)] = [metrics.accuracy_score(y_test, y_pred_knn), run_time]

acc_db
# Out:
#                       Accuracy  Run Time (s)
# Logistic regression   0.785714      0.003473
# Gaussian naive Bayes  0.759740      0.001984
# k Neighbours k=14     0.831169      0.010417

# %%
# support vector with variable kernel - options: {‘linear’, 'poly', ‘rbf’, ‘sigmoid’}
start = time.time()
kernel = 'linear'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

start = time.time()
kernel = 'poly'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

start = time.time()
kernel = 'rbf'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

start = time.time()
kernel = 'sigmoid'
svr = svm.SVC(kernel=kernel, degree=4)
# train the model
svr.fit(x_train,y_train)
# test model on test data
y_pred_svr = svr.predict(x_test)
# measure runtime of model
run_time = time.time() - start

# add prediction and actual to database
db_svr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_svr})

# add statistics to database
acc_db.loc['Support Vector kernel='+kernel] = [metrics.accuracy_score(y_test, y_pred_svr), run_time]

acc_db
# Out:
#                                Accuracy  Run Time (s)
# Logistic regression            0.785714      0.003473
# Gaussian naive Bayes           0.759740      0.001984
# k Neighbours k=14              0.831169      0.010417
# Support Vector kernel=linear   0.798701      0.010911
# Support Vector kernel=poly     0.714286      0.012399
# Support Vector kernel=rbf      0.792208      0.013912
# Support Vector kernel=sigmoid  0.733766      0.008908

# %%
# decision tree classifier models with variable depth and criterion
start = time.time()
decisionTree_model_gini = DecisionTreeClassifier(random_state=4000)
# train the model
decisionTree_model_gini.fit(x_train,y_train)
# test model on test data
y_pred_gini = decisionTree_model_gini.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Decision tree'] = [metrics.accuracy_score(y_test, y_pred_gini), run_time]

start = time.time()
decisionTree_model_entropy = DecisionTreeClassifier(criterion="entropy", random_state=4000)
# train the model
decisionTree_model_entropy.fit(x_train,y_train)
# test model on test data
y_pred_entropy = decisionTree_model_entropy.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Decision tree entropy'] = [metrics.accuracy_score(y_test, y_pred_entropy), run_time]

start = time.time()
decisionTree_model_depth3 = DecisionTreeClassifier(max_depth=3)
# train the model
decisionTree_model_depth3.fit(x_train,y_train)
# test model on test data
y_pred_depth3 = decisionTree_model_depth3.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Decision tree depth=3'] = [metrics.accuracy_score(y_test, y_pred_depth3), run_time]

acc_db
# Out:
#                                Accuracy  Run Time (s)
# Logistic regression            0.785714      0.003473
# Gaussian naive Bayes           0.759740      0.001984
# k Neighbours k=14              0.831169      0.010417
# Support Vector kernel=linear   0.798701      0.010911
# Support Vector kernel=poly     0.714286      0.012399
# Support Vector kernel=rbf      0.792208      0.013912
# Support Vector kernel=sigmoid  0.733766      0.008908
# Decision tree                  0.714286      0.003968
# Decision tree entropy          0.727273      0.004464
# Decision tree depth=3          0.746753      0.001984

# %%
# random forest classifier with variable n
start = time.time()
n = 1000
rfc = RandomForestClassifier(n_estimators=n)
# train the model
rfc.fit(x_train,y_train)
# test model on test data
y_pred_rfc = rfc.predict(x_test)
# measure runtime of model
run_time = time.time() - start

acc_db.loc['Random Forest n='+str(n)] = [metrics.accuracy_score(y_test, y_pred_depth3), run_time]

acc_db
# Out:
#                                Accuracy  Run Time (s)
# Logistic regression            0.785714      0.003473
# Gaussian naive Bayes           0.759740      0.001984
# k Neighbours k=14              0.831169      0.010417
# Support Vector kernel=linear   0.798701      0.010911
# Support Vector kernel=poly     0.714286      0.012399
# Support Vector kernel=rbf      0.792208      0.013912
# Support Vector kernel=sigmoid  0.733766      0.008908
# Decision tree                  0.714286      0.003968
# Decision tree entropy          0.727273      0.004464
# Decision tree depth=3          0.746753      0.001984
# Random Forest n=1000           0.746753      1.719136

# %%
# confusion matrix for best logistic regression model
conf_mat_knn = confusion_matrix(y_test, y_pred_knn)
fig, ax = plt.subplots(figsize=(6,4))
sns.heatmap(conf_mat_knn/np.sum(conf_mat_knn), annot=True, fmt='.2f', annot_kws = {'size':25})
ax.set_ylabel("Actual outcome")
ax.set_xlabel("Predicted outcome")
plt.savefig("diabetes_plots/confusion_matrix_knn.png")

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88       103
#            1       0.82      0.63      0.71        51
#
#     accuracy                           0.83       154
#    macro avg       0.83      0.78      0.80       154
# weighted avg       0.83      0.83      0.82       154

# %%
fpr, tpr = roc_curve(y_test, y_pred_knn)[0:2]
auc = roc_auc_score(y_test, y_pred_knn)

plt.plot(fpr, tpr, color='orange', label=f'ROC, AUC = {auc}')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.savefig("diabetes_plots/roc_knn.png")

# %%
## neural network
start = time.time()
model = Sequential()

##set up the layers
## input layer
model.add(Dense(units= 100, kernel_initializer= 'uniform', activation = 'leaky_relu', input_dim = 7)) 
## hidden layer 1 
model.add(Dense(units= 30, kernel_initializer= 'uniform', activation = 'leaky_relu')) 
##regularization 1
#model.add(Dropout(0.4)) # setting 40% of the data to zero to avoid overfitting
## hidden layer 2
#model.add(Dense(units= 20, kernel_initializer= 'uniform', activation = 'leaky_relu')) 
## regularization 2
model.add(Dropout(0.2)) # another regularisation to avoid overfitting
## output layer
model.add(Dense(units= 1, kernel_initializer= 'uniform', activation = 'sigmoid')) 

## compiling the ANN
model.compile(optimizer = 'adam', loss ='binary_crossentropy', metrics = ['accuracy'])

## train the model with early stopping after enough consecutive epochs without improvement in loss
callback = EarlyStopping(monitor='loss', patience=8)
history = model.fit(x_train, y_train, batch_size = 25, epochs = 100, validation_split=0.25, callbacks=[callback])

## test the model
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
run_time = time.time() - start

print(f"Total run time is: {run_time}")
history_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# c:\Users\aferg\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6311 - loss: 0.6902 - val_accuracy: 0.6753 - val_loss: 0.6746
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7343 - loss: 0.6650 - val_accuracy: 0.7338 - val_loss: 0.6128
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7565 - loss: 0.5877 - val_accuracy: 0.7338 - val_loss: 0.5310
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7565 - loss: 0.5175 - val_accuracy: 0.7468 - val_loss: 0.5142
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7771 - loss: 0.4763 - val_accuracy: 0.7727 - val_loss: 0.5056
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.4993 - val_accuracy: 0.7662 - val_loss: 0.5003
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7662 - loss: 0.4637 - val_accuracy: 0.7597 - val_loss: 0.4979
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7760 - loss: 0.4667 - val_accuracy: 0.7727 - val_loss: 0.4905
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7297 - loss: 0.4938 - val_accuracy: 0.7727 - val_loss: 0.4895
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7704 - loss: 0.4778 - val_accuracy: 0.7727 - val_loss: 0.4861
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7314 - loss: 0.5060 - val_accuracy: 0.7727 - val_loss: 0.4822
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7653 - loss: 0.4642 - val_accuracy: 0.7727 - val_loss: 0.4833
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8111 - loss: 0.4252 - val_accuracy: 0.7727 - val_loss: 0.4833
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7554 - loss: 0.4653 - val_accuracy: 0.7857 - val_loss: 0.4775
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7870 - loss: 0.4277 - val_accuracy: 0.7662 - val_loss: 0.4819
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7721 - loss: 0.4511 - val_accuracy: 0.7727 - val_loss: 0.4799
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7757 - loss: 0.4402 - val_accuracy: 0.7727 - val_loss: 0.4840
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7813 - loss: 0.4584 - val_accuracy: 0.7727 - val_loss: 0.4867
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7605 - loss: 0.4677 - val_accuracy: 0.7662 - val_loss: 0.4837
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7625 - loss: 0.4485 - val_accuracy: 0.7662 - val_loss: 0.4843
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7727 - loss: 0.4664 - val_accuracy: 0.7662 - val_loss: 0.4821
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7530 - loss: 0.4804 - val_accuracy: 0.7662 - val_loss: 0.4860
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7823 - loss: 0.4382 - val_accuracy: 0.7662 - val_loss: 0.4876
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7810 - loss: 0.4343 - val_accuracy: 0.7662 - val_loss: 0.4876
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7765 - loss: 0.4449 - val_accuracy: 0.7662 - val_loss: 0.4866
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7921 - loss: 0.4224 - val_accuracy: 0.7662 - val_loss: 0.4859
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7795 - loss: 0.4344 - val_accuracy: 0.7727 - val_loss: 0.4858
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7744 - loss: 0.4216 - val_accuracy: 0.7662 - val_loss: 0.4885
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7508 - loss: 0.4485 - val_accuracy: 0.7597 - val_loss: 0.4854
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7808 - loss: 0.4451 - val_accuracy: 0.7662 - val_loss: 0.4922
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8268 - loss: 0.3930 - val_accuracy: 0.7727 - val_loss: 0.4908
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8012 - loss: 0.4245 - val_accuracy: 0.7792 - val_loss: 0.4866
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7695 - loss: 0.4325 - val_accuracy: 0.7727 - val_loss: 0.4903
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7741 - loss: 0.4557 - val_accuracy: 0.7792 - val_loss: 0.4890
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7747 - loss: 0.4555 - val_accuracy: 0.7597 - val_loss: 0.4931
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8129 - loss: 0.4189 - val_accuracy: 0.7597 - val_loss: 0.4952
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8036 - loss: 0.4206 - val_accuracy: 0.7662 - val_loss: 0.4932
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7914 - loss: 0.4201 - val_accuracy: 0.7792 - val_loss: 0.4887
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7831 - loss: 0.4303 - val_accuracy: 0.7662 - val_loss: 0.4922
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.4551 - val_accuracy: 0.7727 - val_loss: 0.4917
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7909 - loss: 0.4534 - val_accuracy: 0.7727 - val_loss: 0.4963
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7961 - loss: 0.4057 - val_accuracy: 0.7727 - val_loss: 0.4927
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7809 - loss: 0.4259 - val_accuracy: 0.7922 - val_loss: 0.4856
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7813 - loss: 0.4242 - val_accuracy: 0.7727 - val_loss: 0.4887
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7928 - loss: 0.4124 - val_accuracy: 0.7792 - val_loss: 0.4929
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.4169 - val_accuracy: 0.7857 - val_loss: 0.4945
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7881 - loss: 0.4265 - val_accuracy: 0.7792 - val_loss: 0.4945
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7933 - loss: 0.4028 - val_accuracy: 0.7792 - val_loss: 0.4942
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8131 - loss: 0.4127 - val_accuracy: 0.7792 - val_loss: 0.4927
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7828 - loss: 0.4293 - val_accuracy: 0.7792 - val_loss: 0.4985
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8218 - loss: 0.3879 - val_accuracy: 0.7857 - val_loss: 0.4988
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7931 - loss: 0.4317 - val_accuracy: 0.7792 - val_loss: 0.4925
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8071 - loss: 0.4008 - val_accuracy: 0.7792 - val_loss: 0.4967
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8086 - loss: 0.3826 - val_accuracy: 0.7922 - val_loss: 0.4940
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8003 - loss: 0.3763 - val_accuracy: 0.7727 - val_loss: 0.4906
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8104 - loss: 0.3966 - val_accuracy: 0.7792 - val_loss: 0.4920
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8009 - loss: 0.4112 - val_accuracy: 0.7727 - val_loss: 0.4902
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8097 - loss: 0.3868 - val_accuracy: 0.7792 - val_loss: 0.4977
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.4178 - val_accuracy: 0.7857 - val_loss: 0.4953
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8011 - loss: 0.4121 - val_accuracy: 0.7922 - val_loss: 0.4957
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8137 - loss: 0.3821 - val_accuracy: 0.7857 - val_loss: 0.4977
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8165 - loss: 0.3736 - val_accuracy: 0.7857 - val_loss: 0.4971
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8208 - loss: 0.3917 - val_accuracy: 0.7792 - val_loss: 0.4998
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8129 - loss: 0.4058 - val_accuracy: 0.7857 - val_loss: 0.5007
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8153 - loss: 0.3837 - val_accuracy: 0.7792 - val_loss: 0.5006
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7776 - loss: 0.4222 - val_accuracy: 0.7857 - val_loss: 0.5008
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7931 - loss: 0.4057 - val_accuracy: 0.7727 - val_loss: 0.4990
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8140 - loss: 0.3915 - val_accuracy: 0.7857 - val_loss: 0.5014
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8116 - loss: 0.3979 - val_accuracy: 0.7857 - val_loss: 0.4990
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.3930 - val_accuracy: 0.7792 - val_loss: 0.5040
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7931 - loss: 0.4158 - val_accuracy: 0.7727 - val_loss: 0.5061
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7603 - loss: 0.4427 - val_accuracy: 0.7792 - val_loss: 0.4972
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7809 - loss: 0.4080 - val_accuracy: 0.7857 - val_loss: 0.4978
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8296 - loss: 0.3724 - val_accuracy: 0.7857 - val_loss: 0.5086
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7951 - loss: 0.4184 - val_accuracy: 0.7857 - val_loss: 0.5069
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8084 - loss: 0.3851 - val_accuracy: 0.7857 - val_loss: 0.4959
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8271 - loss: 0.3560 - val_accuracy: 0.7857 - val_loss: 0.5123
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7615 - loss: 0.4465 - val_accuracy: 0.7857 - val_loss: 0.4964
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8072 - loss: 0.3766 - val_accuracy: 0.7792 - val_loss: 0.5074
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8005 - loss: 0.4024 - val_accuracy: 0.7792 - val_loss: 0.5068
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8188 - loss: 0.3820 - val_accuracy: 0.7792 - val_loss: 0.5075
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8214 - loss: 0.3552 - val_accuracy: 0.7857 - val_loss: 0.5120
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8198 - loss: 0.3894 - val_accuracy: 0.7857 - val_loss: 0.5047
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8003 - loss: 0.4060 - val_accuracy: 0.7792 - val_loss: 0.5024
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8029 - loss: 0.3598 - val_accuracy: 0.7792 - val_loss: 0.5161
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7969 - loss: 0.3749 - val_accuracy: 0.7857 - val_loss: 0.5131
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8210 - loss: 0.3794 - val_accuracy: 0.7727 - val_loss: 0.5116
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7975 - loss: 0.3901 - val_accuracy: 0.7857 - val_loss: 0.5106
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8001 - loss: 0.3923 - val_accuracy: 0.7792 - val_loss: 0.5079
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8113 - loss: 0.4046 - val_accuracy: 0.7792 - val_loss: 0.5096
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8144 - loss: 0.3674 - val_accuracy: 0.7922 - val_loss: 0.5096
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8050 - loss: 0.3893 - val_accuracy: 0.7792 - val_loss: 0.5149
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8145 - loss: 0.3584 - val_accuracy: 0.7857 - val_loss: 0.5113
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8464 - loss: 0.3354 - val_accuracy: 0.7792 - val_loss: 0.5167
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7766 - loss: 0.4124 - val_accuracy: 0.7727 - val_loss: 0.5125
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7917 - loss: 0.4194 - val_accuracy: 0.7792 - val_loss: 0.5126
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8107 - loss: 0.3674 - val_accuracy: 0.7857 - val_loss: 0.5162
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7723 - loss: 0.3971 - val_accuracy: 0.7792 - val_loss: 0.5160
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - loss: 0.3784 - val_accuracy: 0.7727 - val_loss: 0.5190
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7705 - loss: 0.4237 - val_accuracy: 0.7727 - val_loss: 0.5222
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Total run time is: 10.242976665496826

# %%
# plot of training and validation loss
plt.plot(history_df.loc[:, ['loss']], "#CD5C5C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")
plt.savefig("diabetes_plots/loss_chart.png")

# %%
# Training and validation accuracy plot
plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("diabetes_plots/accuracy_chart.png")

# %%
# confusion matrix for neural network
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot = True, annot_kws = {'size':25})
plt.ylabel("Actual outcome")
plt.xlabel("Predicted outcome")
plt.savefig("diabetes_plots/confusion_matrix_ann.png")

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87       103
#            1       0.76      0.67      0.71        51
#
#     accuracy                           0.82       154
#    macro avg       0.80      0.78      0.79       154
# weighted avg       0.81      0.82      0.82       154

# %%
fpr, tpr = roc_curve(y_test, y_pred)[0:2]
auc = roc_auc_score(y_test, y_pred)

plt.plot(fpr, tpr, color='orange', label=f'ROC, AUC = {auc}')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.savefig("diabetes_plots/roc_ann.png")

# %%
# accuracy for final neural network
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.8181818181818182
